# %% [markdown]
# <a href="https://colab.research.google.com/github/danferoso/Entregas/blob/main/Manejo_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (3.5.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (4.39.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
#grafica 1
Audi = [10,20,30,40]
BMW = [12,15,22,30]
Ferrari = [10,14,13,18]
labels = ['2018','2019','2020','2021']

x_pos = np.arange(1,2*len(labels),2)
wd = 0.6

fig, ax1 = plt.subplots()
ax1.bar(x_pos,Audi,color='green',width=wd, label='Audi')
ax1.bar(x_pos+0.6,BMW,color='blue',width=wd, label='BMW')
ax1.bar(x_pos+1.2,Ferrari,color='red',width=wd, label='Ferrari')
ax1.tick_params(axis='x')
ax1.set_xlabel('Años')
ax1.set_ylabel('Carros')

ax1.set_xticks(x_pos+0.6)
ax1.set_xticklabels(labels)
plt.legend(loc='best')

# %%
from matplotlib import markers
x = np.linspace(0,10,36)
y = np.sin(x)
limx=[0,2*np.pi]
limy=[-1,0,1]


fig, ax = plt.subplots()

ax.plot(x,y,color='green', marker='*')


ax.set_xlim([0,2*np.pi])
ax.set_ylim([-1.2,1.2])

ax.set_xlabel('Tiempo')
ax.set_ylabel('Amplitud')
ax.set_title('Simple Title')
ax.legend()
ax.set_yticks(limy)
ax.set_xticks(limx)
ax.grid(axis = 'y', color = 'black', linestyle = 'dashed')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
x_1 = np.linspace(0, 10, 200)
y_1=[] 
y_2=[]
for i in x_1:
   res = np.exp(i)
   y_1.append(res) 
for i in x_1:
   res = np.log(i)
   y_2.append(res) 

fig, ax3 = plt.subplots()
twin_ax3 = ax3.twinx() 
ax3.plot(x_1,y_1)
twin_ax3.plot(x_1,y_2)
ax3.set_yscale("log")

ax3.set_ylabel("e^x")
twin_ax3.set_ylabel("log(x)")
# Out:
# <ipython-input-178-4df22aea7207>:8: RuntimeWarning: divide by zero encountered in log
#   res = np.log(i)
# Text(0, 0.5, 'log(x)')

# %%
from matplotlib.gridspec import GridSpec

fig = plt.figure(figsize=(18,6))
gs = GridSpec(nrows=30,ncols=20)

#Gráfica 1 de barras 
ax1 = fig.add_subplot(gs[0:7,:13])

ax1.bar(x_pos,Audi,color='green',width=wd, label='Audi')
ax1.bar(x_pos+0.6,BMW,color='blue',width=wd, label='BMW')
ax1.bar(x_pos+1.2,Ferrari,color='red',width=wd, label='Ferrari')
ax1.tick_params(axis='x')
ax1.set_xlabel('Años')
ax1.set_ylabel('Carros')

ax1.set_xticks(x_pos+0.6)
ax1.set_xticklabels(labels)
plt.legend(loc='upper left')


#Gráfica 2 seno
ax2 = fig.add_subplot(gs[12:30,:13])

ax2.plot(x,y,color='green', marker='*')

ax2.set_xlim([0,2*np.pi])
ax2.set_ylim([-1.2,1.2])

ax2.set_xlabel('Tiempo')
ax2.set_ylabel('Amplitud')
ax2.set_title('Seno')
ax2.legend()
ax2.set_yticks(limy)
ax2.set_xticks(limx)
ax2.grid(axis = 'y', color = 'black', linestyle = 'dashed')


#Gráfico 3 exponencial
ax3 = fig.add_subplot(gs[:,14:])
twin_ax3 = ax3.twinx() 
ax3.plot(x_1,y_1)
twin_ax3.plot(x_1,y_2)
ax3.set_yscale("log")

ax3.set_ylabel("e^x")
twin_ax3.set_ylabel("log(x)")
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'log(x)')
